# %%
from torchvision.transforms.functional import to_pil_image

from model_handler import DeepLabV3ResNet101ModelHandler, compare_images
# Out:
# /Users/henry529/Projects/MukikikiCD/VENV/lib/python3.9/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
handler = DeepLabV3ResNet101ModelHandler()
print(handler.categories)
# Out:
# ['__background__', 'aeroplane', 'bicycle', 'bird', 'boat', 'bottle', 'bus', 'car', 'cat', 'chair', 'cow', 'diningtable', 'dog', 'horse', 'motorbike', 'person', 'pottedplant', 'sheep', 'sofa', 'train', 'tvmonitor']

# %%
mask1, mask2 = handler.predict(
    imagePathList=["./images/厨房1.jpg", "./images/厨房2.jpg"],
    categoryList=["person"],
)
compare_images(to_pil_image(mask1), to_pil_image(mask2))
# Out:
# /Users/henry529/Projects/MukikikiCD/VENV/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(

# %%
to_pil_image(mask1)
# Out:
# <PIL.Image.Image image mode=L size=924x520>

# %%
to_pil_image(mask2)
# Out:
# <PIL.Image.Image image mode=L size=924x520>

# %%
mask1, mask2 = handler.predict(
    imagePathList=["./images/网球1.jpg", "./images/网球2.jpg"],
    categoryList=["person"],
)
compare_images(to_pil_image(mask1), to_pil_image(mask2))

# %%
to_pil_image(mask1)
# Out:
# <PIL.Image.Image image mode=L size=725x520>

# %%
to_pil_image(mask2)
# Out:
# <PIL.Image.Image image mode=L size=725x520>
